# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreAntonioCampos/FIAP_POS/blob/main/Modulo1_Analise_Exploratorio_Dados_03.06.24_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.IMPORTANDO OS DADOS E PRIMEIRAS VISUALIZAÇÕES

# %% [markdown]
# #IMPORTANDO AS BIBLIOTECAS

# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #CARREGANDO A TABELA E TRATANDO AS COLUNAS
#
# * encoding ='ISO-8859-1' = *Transformando em UTF-8*
# * encoding = 'latin1'  *Transformando em UTF-8*
# * skiprows=3   *Desconsidera a qtd X das primeiras linhas da tabela*
# * sep = ";"  *Informando que o separador é ; (ponto e virgula)*
# * skipfooter=12   *Excluindo qtd X de linhas finais *
# * Thousands = "."   *Trocando a ,(virgula) por . (ponto) em separador de milhar no valor*
# * decimal = ","   *Informando que o separador de casas decimais é , (virgula)*
# * dados.head()   *Visualiza os 5 primeiros itens do meu Dataframe*
# * dados.head(10)   *Visualiza a qtd X dos primeiros itens do meu Dataframe*

# %%
# Lendo o arquivo CSV
arquivo = pd.read_csv('/content/A150850189_28_143_208 (2).csv',encoding="ISO-8859-1",skiprows=3,sep=";",skipfooter=12,thousands=".",decimal=",")
dados = arquivo

# Visualizando o DataFrame
display(dados.head(5))
# Out:
# <ipython-input-297-1e885fcb7363>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   arquivo = pd.read_csv('/content/A150850189_28_143_208 (2).csv',encoding="ISO-8859-1",skiprows=3,sep=";",skipfooter=12,thousands=".",decimal=",")
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# ...

# %% [markdown]
# #VISUALIZAR O DATAFRAME COMPLETO
#
# * display(dataframe)

# %%
display(dados)
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %% [markdown]
# #VISUALIZANDO OS TIPOS DE DADOS
#
# * dados.dtypes

# %%
tipos_de_dados = dados.dtypes
tipos_de_dados.head()
# Out:
# Unidade da Federação    object
# 1992/Mar                object
# 1992/Abr                object
# 1993/Mai                object
# 1993/Dez                object
# dtype: object

# %% [markdown]
# #VISUALIZANDO AS COLUNAS DO DATAFRAME
#
# VISUALIZAR NA VERTICAL
#
# list(df.columns)
#
#
# VISUALIZAR NA HORIZONTAL
#
# variavel = list(df.columns)
#
# print(variavel)

# %%
colunas = list(dados.columns)
print(colunas)
# Out:
# ['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez', '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov', '1995/Jan', '1995/Mar', '1995/Jun', '1995/Ago', '1995/Dez', '1996/Fev', '1996/Mar', '1996/Ago', '1996/Dez', '1997/Fev', '1997/Nov', '1998/Fev', '1998/Mar', '1998/Jul', '1998/Ago', '1998/Set', '1998/Out', '1998/Dez', '1999/Fev', '1999/Mar', '1999/Mai', '1999/Jul', '1999/Ago', '1999/Set', '1999/Out', '1999/Nov', '1999/Dez', '2000/Jan', '2000/Fev', '2000/Mar', '2000/Abr', '2000/Mai', '2000/Jun', '2000/Jul', '2000/Ago', '2000/Set', '2000/Out', '2000/Nov', '2000/Dez', '2001/Jan', '2001/Fev', '2001/Mar', '2001/Abr', '2001/Mai', '2001/Jun', '2001/Jul', '2001/Ago', '2001/Set', '2001/Nov', '2001/Dez', '2002/Jan', '2002/Fev', '2002/Mar', '2002/Mai', '2002/Jun', '2002/Jul', '2002/Out', '2002/Nov', '2002/Dez', '2003/Jan', '2003/Fev', '2003/Mar', '2003/Abr', '2003/Jun', '2003/Jul', '2003/Ago', '2003/Out', '2003/Nov', '2003/Dez', '2004/Jan', '2004/Fev', '2004/Mar', '
# ...

# %% [markdown]
# #VISUALIZANDO AS INFORMAÇÕES DO DATAFRAME
# * dataframe.info()

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %% [markdown]
# #FORMATANDO AS COLUNAS DE FLOAT QUE CARREGAM
#
# * Carregam com 1.512685e+07 e quero transformar em 15126846.64
#
# pd.options.display.float_format = "{:.2f}".format

# %%
pd.options.display.float_format = "{:.2f}".format
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %% [markdown]
# #CRIANDO VARIAVEIS NUMERICAS PARA TRABALHAR COM MÉDIA DE VALORES

# %%
# Selecionando apenas as colunas numéricas para trabalhar com médias de valores
dados_numericos = dados.select_dtypes(include='number')

# Preenchendo os valores vazios com 0
dados_vazios_preenchidos = dados_numericos.fillna(0)

# Adicionando a coluna "Unidade da Federação" de volta ao DataFrame
dados_vazios_preenchidos.insert(0, "Unidade da Federação", arquivo["Unidade da Federação"])

# A variável final é chamada "dados"
dados = dados_vazios_preenchidos

display(dados_numericos)
display(dados_vazios_preenchidos)

dados.head()
# Out:
#      2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez      2008/Jan  \
# 0     4209.37   16397.03   133645.19   346912.84   711758.31    1829559.71
# 1    10470.07   14001.71    86200.85   301323.68   769612.36    1731744.62
# 2    35752.72   45570.64   416012.30  2020381.79  5949408.99   11419210.08
# 3     4785.91   11858.63    43852.67   369328.51   470676.43     808448.39
# 4   181159.29  433414.74  1893197.50  5105406.44 13162823.43   21762104.16
# 5    33672.74  104822.98   118378.28   226661.18   844019.90    1329876.61
# 6     4113.76   76633.06   343702.61  1068685.94  3022200.87    5136474.61
# 7   385330.18 1018352.93  2277717.78  4334468.23  8832514.85   21551600.33
# 8   220788.25  353468.67  1078182.68  2406035.32  4929772.93   11375419.37
# 9   357904.65  572356.18  1865065.71  5131814.39 10798042.86   32444328.54
# 10  134605.36  272088.08   684678.30  1695824.89  4730811.68   11763899.23
# ...

# %% [markdown]
# #MÉDIA DE VALORES

# %%
media = dados_numericos.mean()
display(media)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %% [markdown]
# # MÉDIA SÉRIE CAPTURADA

# %%
media_ago2008 = dados["2008/Ago"].mean()
display(media_ago2008)
# Out:
# 26645398.35703704

# %% [markdown]
# #CAPTURANDO COLUNA ESPECIFICA
#
# * 1.COLUNA  *dataframe['nome_coluna']*
#
# * MAIS DE 1 COLUNA *dataframe[['nome_coluna_1','nome_coluna_2','nome_coluna_2']]*

# %%
captura_1coluna = dados["2008/Ago"]
captura_mais_1coluna = dados[['2008/Ago', '2008/Set','2008/Out','2008/Nov','2008/Dez']]

captura_mais_1coluna.head()
# Out:
#      2008/Ago    2008/Set    2008/Out    2008/Nov    2008/Dez
# 0  2938286.29  2843930.91  2878153.20  2780022.62  2651804.89
# 1  1886871.84  2084884.80  2230838.45  2122013.12  2196651.69
# 2  8331763.97  8148089.92  7681661.02  7761445.21  7764782.66
# 3  1045291.11  1003740.89  1055063.43  1223200.73  1236529.18
# 4 23259148.28 23667690.01 23352577.75 23537613.41 23836162.40

# %% [markdown]
# # 2. GRAFICOS PARA VISUALIZAÇÃO

# %% [markdown]
# #PLOTAR OS DADOS = CRIAR UM GRAFICO
#
# * x = Informar a coluna do eixo X
# * y = Informar a coluna do eixo y
# * kind='bar'  *define o tipo de gráfico como de barras.*
# * figsize=(10,7)  * define o tamanho da figura do gráfico*
# * yaxis *se refere ao eixo y*.
# * set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))    =  *define que os valores no eixo y serão formatados como números de ponto flutuante com duas casas decimais e separador de milhares.*
#
# * plt.xticks(rotation=45)    *Inclinar as legendas em 45 graus*
# * plt.title("TITULO"): *Adiciona um título ao gráfico.*
# * plt.show():   *Exibe o gráfico na tela*

# %%
barras_ago2008 = dados.plot(x = "Unidade da Federação", y = "2008/Ago", kind = "bar", figsize=(10,7))
barras_ago2008.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

linhas_ago2008 = dados.plot(x = "Unidade da Federação", y = "2008/Ago", figsize=(10,7))
linhas_ago2008.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# Adicione a legenda
plt.title("VALOR UNIDADE")

# Exiba o gráfico
plt.show(barras_ago2008)
plt.show(linhas_ago2008)

# %% [markdown]
# # ********************************************************************************

# %%
# Desafio 1: executar o gráfico anterior com o mês mais recente

#Com esse comando consigo visualizar no meu df a coluna mais recente que neste caso é 2021/Ago  dados.min() ou dados.max()
dados.min()

#Criando e formatando o Grafico
axis = dados.plot(x = 'Unidade da Federação',y='2021/Ago', figsize=(10,7), kind= 'bar')
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# Adicionando a legenda
plt.title("AGO-2021")

# Exiba o gráfico
plt.show()

# %%
#Desafio 2: deixar as legendas ânguladas (0, 45 etc) para facilitar a leitura

# Criando e formatando o gráfico
axis = dados.plot(x='Unidade da Federação', y='2021/Ago', figsize=(10, 7))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# Adicionando a legenda
plt.title("AGO-2021")

# Inclinar as legendas em 45 graus
plt.xticks(rotation=45)

# Exiba o gráfico
plt.show()

# %% [markdown]
# #FASE 1- AULA 3 - ANALISE EXPLORATORIA DE DADOS - MANIPULAÇÃO DE DADOS I

# %% [markdown]
# AULA MANIPULAÇÃO DE DADOS I

# %% [markdown]
# #VISUALIZANDO AS COLUNAS DO DF
#
# * df.columns

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov',
#        '2007/Dez', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        ...
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai',
#        '2021/Jun', '2021/Jul', '2021/Ago', 'Total'],
#       dtype='object', length=171)

# %% [markdown]
# #VISUALIZANDO O INDICE DAS COLUNAS DO MEU DF
#
# * Usei a média pra saber em quais colunas numericas temos dados
# * Tranformei elas em um indice
# * df.index

# %%
dados_numericos.mean().index
# Out:
# Index(['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan',
#        '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai',
#        ...
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai',
#        '2021/Jun', '2021/Jul', '2021/Ago', 'Total'],
#       dtype='object', length=170)

# %% [markdown]
# #TRANSFORMANDO ESSE INDICE EM UMA LISTA
#
# Com isso consigo usar apenas as colunas que tem dados
#
# * df.tolist()
# * df.insert()
# * df[:5]

# %%
colunas_usaveis = dados_numericos.mean().index.tolist()
#Como não queremos apenas as colunas de valores(Usaveis) vamos inserir a primeira coluna com os dados da Unidade da Federeção
#que no Python é a posição 0
colunas_usaveis.insert(0, "Unidade da Federação")

# Usando o colchetes[] com : numero, informamos quantos itens da lista de Python queremos imprimir. Não chamo o head porque é uma lista
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %% [markdown]
# #PARA UTILIZAR O DF(COLUNAS_USAVEIS)
#
# Esperamos que todos o resultado tenham dados preenchidos
#
# *df[colunas_usaveis]

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %% [markdown]
# #ORGANIZANDO O DF
#
# * Quero que cada linha seja o estado e não o indice que aparece o contador 0,1,2,3...
#
# * variavel = df.set_index("Coluna_que_eu_quero_como_indice")

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %% [markdown]
# #LOCALIZAR UM ELEMENTO PELO INDICE
#
# * loc é a busca pelo indice
# * colchete é a busca ela coluna
# * df.loc["elemento"]

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %% [markdown]
# #LOCALIZAR UM ELEMENTO PELA LINHA.
#
# iloc = informa o numero da linha
#
# df.iloc[2]
#
# Lembrando que se quero trazer a linha 2 eu uso o 1 porque o Python começa com 0

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %% [markdown]
# #AGORA QUE JA TEMOS OS DADOS USAVEIS, VAMOS PLOTAR ELES

# %%
dados_usaveis.plot(figsize=(15,8))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %% [markdown]
# #QUERO TRANSFORMAR EM UMA SERIE TEMPORAL
#
# * No eixo X eu quero o tempo
# * As linhas eixo Y eu quero as Unidades da Federação
# * Para este caso quando quero trocar totalmente, eu uso o Transpor
#
# df.T.head()

# %%
#O que era linha vira coluna
#O que era coluna vira linha
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %% [markdown]
# #AGORA APÓS TRANSPOR OS DADOS, TEMOS UM GRAFICO PROXIMO MAS AINDA MOSTRA UM SALTO ENORME NO FINAL.

# %%
dados_usaveis.T.plot(figsize=(15,8))
# Out:
# <Axes: >

# %% [markdown]
# #O MOTIVO É QUE PROVAVELMENTE TEMOS UMA LINHA DE TOTAIS NO FINAL.
#
# Para saber usamos:
# *df.T.tail()
#
# *Podemos ver a coluna de totais que está distoando do meu grafico.

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2021/Mai               17659855.79   4326882.24   23973537.71   3681417.80
# 2021/Jun               14435903.47   3458187.11   22175398.40   3475205.55
# 2021/Jul               11834435.10   2302711.01   21614943.55   3320807.96
# 2021/Ago                7371334.84   1196754.85   13806958.66   2907871.07
# Total                1088059702.25 475290315.34 2061943006.93 352546288.71
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Mai               50907226.77   5672086.52   10161783.68   55324683.42
# 2021/Jun               43876590.47   5469150.38    6349488.16   51958573.27
# 2021/Jul               33718084.12   4136950.62    4610170.61   37775425.78
# 2021/Ago               20837865.89   1875241.91    2304080.49   25779674.83
# Total                4968811817.17 337181964.14 1110344733.46 4161325769.23
#
# ...

# %% [markdown]
# #PARA REMOVER ESSE TOTAL, VAMOS DROP A COLUNA DO TOTAL
#
# *df.drop("Nome do Indice", axis=0)
#
# *axis=0 Procura nas linhas, é o padrão
#
# *axis=1 Procura nas colunas

# %%
#Quando eu chamo o dados_usaveis = dados_usaveis.drop("Total",axis=1) eu sestou removendo dos dados principais usaiveis antes de TRANSPOR
dados_usaveis = dados_usaveis.drop("Total",axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %% [markdown]
# #REPOSICIONAR A LEGENDA DO GRAFICO

# %%
# Cria o gráfico transposto
dados_usaveis.T.plot(figsize=(12,6))

# Adiciona um título ao gráfico
plt.title('Título do Gráfico')

# Reposiciona a legenda no centro na parte superior
plt.legend(loc='upper right')

# Nomeia o eixo x e o eixo y
plt.xlabel('Ano')
plt.ylabel('Valores')

# Mostra o gráfico
plt.show()

# %% [markdown]
# #FASE 1- AULA 3 - ANALISE EXPLORATORIA DE DADOS - MANIPULAÇÃO DE DADOS II

# %% [markdown]
# #O grafico anterior não deixa claro o resultado. VAMOS TRAZER UMA AMOSTRA INICIAL para demonstrar uma visão resumida é escolher de forma aleatória esses dados.
#
# Vou trazer os 7 primeiros estados

# %%
dados_usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# #AMOSTRA ALETÓRIA DOS DADOS, ONDE É UMA FORMA MAIS JUSTA É TRAZER UMA AMOSTRA DOS DADOS.
#
# * SAMPLE  = Toda vez que eu executar vai trazer daos aleatórios diferentes
#
# * df.sample()   Vai trazer 1 amostra aleatória dos dados.
#
# * df.sample(n=?)   Vai trazer a qtd de amostrar que eu determinar no n= dos dados.
#
# * df.sample(7) Posso informar diretamente a quantide de amostra aleatória que eu quero
#
# * df.sample(frac=0,10) Posso informar se eu qeuiser em percentual por exemplo 10% de amostra aleatória

# %%
dados_usaveis.sample(n=7)
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
#
#                           2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 43 Rio Grande do Sul   30134255.70   51064610.03  45897704.82  52928695.92
# 13 Amazonas             5949408.99   11419210.08   7934652.10   8641517.13
# 31 Minas Gerais        43429517.54  206493861.30  70301089.50  79119005.51
# ...

# %%
#Amostra de 20%
dados_usaveis.sample(frac=0.20)
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
# 23 Ceará             357904.65 572356.18 1865065.71 5131814.39 10798042.86
# 53 Distrito Federal  191951.47 769966.25 2165619.56 3813256.48  7121965.42
# 32 Espírito Santo     57408.11 284224.80 1152115.25 2296383.23  5724199.54
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 27 Alagoas           16623799.85  8112220.30  9210505.56 10466691.94
# 23 Ceará             32444328.54 27643304.86 30085370.22 31376221.00
# 53 Distrito Federal  10561085.46 10215956.80 11627918.26 11922015.36
# 32 Espírito Santo    16212109.41 10032886.43 12262049.08 12453466.98
#
# ...

# %% [markdown]
# #GRAFICO (PLOTAR) ESSA AMOSTRA

# %%
dados_usaveis.sample(n=7).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# #IMPLANTANDO ALGORITIMOS DE ALEATORIEDADE PARA QUE TODAS VEZ QUE EU OU OUTRA PESSOA TRAGA NUMEROS ALETÓRIOS, SE A BASE FOR IGUAL SERÁ SEMPRE O MESMO DADO

# %%
import numpy as np

np.random.seed(524387)

dados_usaveis.sample(7)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# Adicionar o Total de volta nos dados_usaveis
#
# Por padrão o Pyhton escolhe o eixo 0 mas vamos optar neste caso pelo eixo 1

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis=1)

#Ordenando forma decrecente de valot Total
dados_usaveis = dados_usaveis.sort_values(by="Total", ascending=False)
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %% [markdown]
# #FASE 1- AULA 3 - ANALISE EXPLORATORIA DE DADOS - MANIPULAÇÃO DE DADOS III

# %% [markdown]
# Ordenar o nosso datafreme para que na primeiera linha tenha a linha com mais gasto, e na ultima com menor gasto(ordenação)
#
# Desafio: Adicionar uma coluna com a região de cada estado.
#
# Desafio: Adicone seu estado nessa lista de 7 estados (dados_dos_7_estados).

# %%
#Visualizando os dados_usaveis
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %% [markdown]
# #Ordenar os dados (sort_values)   Por padrão para menor pro maior = Crescente

# %%
#Ordenar os dados (sort_values) dataframe.sort_values(by = "Por qual coluna")
dados_usaveis.sort_values(by="Total")
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 28 Sergipe               27453.63   78565.19   122952.94   775705.52
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 51 Mato Grosso           63562.50  232444.62   927219.59  1740439.60
# 27 Alagoas              104243.75  174024.90   595544.54  1125396.73
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 50 Mato Grosso do Sul   199556.12  573675.41  1069816.66  1995899.52
# 53 Distrito Federal     191951.47  769966.25  2165619.56  3813256.48
# ...

# %% [markdown]
# #Ordenar os dados descrecente (sort_values)

# %%
#Ordenar os dados (sort_values) dataframe.sort_values(by = "Por qual coluna") para maior pra menor descrecente
#Por padrão é ascendente, então colocamos ascending = falso
ordenados_por_total = dados_usaveis.sort_values(by = "Total", ascending=False)
ordenados_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %% [markdown]
# #Removendo a coluna Total, função drop e axis=1(coluna)
#
# Implace = True significa que eu quero que essas modificações ocorram na própria tabela ao inves de eu colocar ordenados_por_total = ordenados_por_total

# %%
ordenados_por_total.drop("Total",axis=1, inplace=True)
ordenados_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %% [markdown]
# #Plotar mas no 5 primeiros e com Transpor

# %%
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# #Como mês de Janeiro de 2008 foi um meês muito importante, vemos um salto enorme no grafico, por exemplo uma migração de banco de dados que acabou acumulando valores em um determinado periodo e distoa muito dos dados anteriores. Veja que todos os estados tem um comportamento igual.
# Vamos descondiderar algumas colunas.
#
# 1º Passo remover algumas colunas dataframe.columns[Numero de colunas:]

# %%
#Estou jogando fora as 6 peimeirs colunas
ordenados_por_total.columns[6:]
# Out:
# Index(['2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai', '2008/Jun', '2008/Jul',
#        '2008/Ago', '2008/Set', '2008/Out', '2008/Nov',
#        ...
#        '2020/Nov', '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr',
#        '2021/Mai', '2021/Jun', '2021/Jul', '2021/Ago'],
#       dtype='object', length=163)

# %%
#Estou renomeando a variavel anterior como colunas interessadas
colunas_interessadas = ordenados_por_total.columns[6:]

# %%
#Renomeando a variavel para ordenados_por_total = ordenados_por_total[ja como filtro das colunas que eu quero trazer]
ordenados_por_total= ordenados_por_total[colunas_interessadas]

#ao plotar conseguimos ver os 5 estados em aquele mês que ditoava dos demais dados
ordenados_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <Axes: >

# %% [markdown]
# #FASE 1 - ANÁLISE EXPLORATÓRIA DE DADOS
#
# #AULA 4 - ANÁLISE DE GRAFICOS E CRIAÇÃO DE HIPÓTESES

# %%
#Para que o resultado não fique 5000.000,00 eu divido por 1Milhão e tenho o resultado com 500 por exemplo
ordenados_por_total = ordenados_por_total/1_000_000

# %%
#Trazendo o grafico anterior
axis = ordenados_por_total.head(5).T.plot(figsize=(10,6))

#Titulo do eixo Y
axis.set_ylabel("Gasto Aprovado em Milhões de Reaiss")
#Titulo do eixo X
axis.set_xlabel("mes")
# Out:
# Text(0.5, 0, 'mes')

# %% [markdown]
# #ESCOLHER ALGUNS MESES, POR EXEOMPLO VOU PEGAR DA COLUNA 47 EM DIANTE

# %%
#Estou escolhendo de 2012 em diante
meses_filtrados = ordenados_por_total.columns[47:]

#Estou chamando na variavel ordenados por coluna, os 3 primeiros meses
axis = ordenados_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
axis.set_ylabel("Gasto Aprovado em Milhões de Reaiss")
axis.set_xlabel("mes")
# Out:
# Text(0.5, 0, 'mes')

# %% [markdown]
# #Posso criar uma função para não ter que escrever toda hora a formatação do grafico

# %%
#Preciso dar um tab pra que as linhas abaixo fiquem dentro da função
def plota_gastos_por_mes(dados, figsize=(10,6)):
  axis = dados.T.plot(figsize=figsize)
  axis.set_ylabel("Gasto Aprovado em Milhões de Reaiss")
  axis.set_xlabel("mes")

# %%
#Chamando a função
plota_gastos_por_mes(ordenados_por_total[meses_filtrados].head(3))

# %% [markdown]
# #Alterando o limite para que os numeros do eixo Y fiquem mais claros

# %%
plota_gastos_por_mes(ordenados_por_total[meses_filtrados].head(3))

#ylim quer dizer limite do eixo y
plt.ylim(0,650)
# Out:
# (0.0, 650.0)

# %%
#Pegando os ultimos 12 Meses
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-12:]].head(3))
plt.ylim(0,650)
# Out:
# (0.0, 650.0)

# %%
#Alterando o gráfico do eixo X para não dar a impressão que o gasto do ultimo é muito diferente do maior. A prática mais correta é começãr no 0
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-12:]].head(3))
plt.ylim(80,650)
# Out:
# (80.0, 650.0)

# %%
#Pegando os ultimos 5 anos (60 Meses)
plota_gastos_por_mes(ordenados_por_total[ordenados_por_total.columns[-60:]].head(3))
plt.ylim(0,650)
# Out:
# (0.0, 650.0)

# %%
#Pegando todos os meses
plota_gastos_por_mes(ordenados_por_total.head(3))
plt.ylim(0,650)
# Out:
# (0.0, 650.0)

# %%
#alterando o limite do eixo X)
plota_gastos_por_mes(ordenados_por_total.head(5),figsize = (20,6))
plt.ylim(0,640)
# Out:
# (0.0, 640.0)

# %% [markdown]
# #AGRUPANDO POR ANO PARA MELHORAR A VISUALIZAÇÃO DO GRAFICO
