# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreAntonioCampos/FIAP_POS/blob/main/FASE_2_AULA%202%20-%20Analise%20Explorat%C3%B3ria%20de%20Dados%20EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 1 E 2 Análise Exploratória de Dados (EDA)**

# %%
import pandas as pd

# %%
df = pd.read_excel('dataset_rolling_stones.xlsx')

# %%
df.head()
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
df.shape
# Out:
# (1610, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1610 entries, 0 to 1609
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              1610 non-null   object
#  1   album             1610 non-null   object
#  2   release_date      1610 non-null   datetime64[ns]
#  3   track_number      1610 non-null   int64
#  4   acousticness      1610 non-null   float64
#  5   danceability      1610 non-null   float64
#  6   energy            1610 non-null   float64
#  7   instrumentalness  1610 non-null   float64
#  8   liveness          1610 non-null   float64
#  9   loudness          1610 non-null   float64
#  10  speechiness       1610 non-null   float64
#  11  tempo             1610 non-null   float64
#  12  valence           1610 non-null   float64
#  13  popularity        1610 non-null   int64
#  14  duration_ms       1610 non-null   int64
# ...

# %% [markdown]
# #DESDE QUANDO ELES LANÇAM MUSICAS, QUANDO ELES COMEÇARAM?
# #print() = Imprimir
# #Data Inicial = é o titulo que vai aparecer no meu print
# #df["nome_coluna"]
# #min() = Mostra a data mais antiga

# %%
#FUNÇÃO mim()
print("Data Inicial: ", df["release_date"].min())   #Data de inicio
# Out:
# Data Inicial:  1964-04-16 00:00:00

# %%
#FUNÇÃO max()
print("Data Final: ",df["release_date"].max())  #Ultima data
# Out:
# Data Final:  2022-06-10 00:00:00

# %%
#Dados Nulos  .isnul().sum()
df.isnull().sum()
# Out:
# name                0
# album               0
# release_date        0
# track_number        0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# liveness            0
# loudness            0
# speechiness         0
# tempo               0
# valence             0
# popularity          0
# duration_ms         0
# dtype: int64

# %%
#Dados Nulos .isnul()
df.isnull()
# Out:
#        name  album  release_date  track_number  acousticness  danceability  \
# 0     False  False         False         False         False         False
# 1     False  False         False         False         False         False
# 2     False  False         False         False         False         False
# 3     False  False         False         False         False         False
# 4     False  False         False         False         False         False
# ...     ...    ...           ...           ...           ...           ...
# 1605  False  False         False         False         False         False
# 1606  False  False         False         False         False         False
# 1607  False  False         False         False         False         False
# 1608  False  False         False         False         False         False
# 1609  False  False         False         False         False         False
#
# ...

# %%
#Dados duplicados duplicated()
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1605    False
# 1606    False
# 1607    False
# 1608    False
# 1609    False
# Length: 1610, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 6

# %%
#ver que linhas estão duplicada
df[df.duplicated()]
# Out:
#                         name                        album release_date  \
# 928  Some Girls - Remastered  Some Girls (Deluxe Version)   1978-06-09
# 929        Lies - Remastered  Some Girls (Deluxe Version)   1978-06-09
# 935                 Claudine  Some Girls (Deluxe Version)   1978-06-09
# 939           No Spare Parts  Some Girls (Deluxe Version)   1978-06-09
# 940      Don't Be A Stranger  Some Girls (Deluxe Version)   1978-06-09
# 946             Petrol Blues  Some Girls (Deluxe Version)   1978-06-09
#
#      track_number  acousticness  danceability  energy  instrumentalness  \
# 928             4        0.5270         0.474   0.938          0.520000
# 929             5        0.4370         0.382   0.997          0.950000
# 935             1        0.0144         0.439   0.977          0.022100
# 939             5        0.2400         0.594   0.762          0.000015
# 940             6        0.0610         0.720   0.867          0.029700
# ...

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 3 Análise Exploratória de Dados (EDA)**

# %%
#Estatistica descritiva
df.describe()
# Out:
#                         release_date  track_number  acousticness  \
# count                           1610   1610.000000   1610.000000
# mean   1992-04-23 12:57:14.534161536      8.613665      0.250475
# min              1964-04-16 00:00:00      1.000000      0.000009
# 25%              1970-09-04 00:00:00      4.000000      0.058350
# 50%              1986-03-24 00:00:00      7.000000      0.183000
# 75%              2017-12-01 00:00:00     11.000000      0.403750
# max              2022-06-10 00:00:00     47.000000      0.994000
# std                              NaN      6.560220      0.227397
#
#        danceability       energy  instrumentalness    liveness      loudness  \
# count   1610.000000  1610.000000       1610.000000  1610.00000   1610.000000
# mean       0.468860     0.792352          0.164170     0.49173  -6406.640075
# min        0.104000     0.141000          0.000000     0.02190 -24408.000000
# ...

# %%
#Transformar milesegundos(ms) em minutos coluna duration_ms / dividor por 60mil
#df["nome_nova_coluna"] = df["nome_da_coluna que vou calcular"] / 60000

df["duracao_em_min"] = df["duration_ms"]/60000
df.head()
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
df.describe()
# Out:
#                         release_date  track_number  acousticness  \
# count                           1610   1610.000000   1610.000000
# mean   1992-04-23 12:57:14.534161536      8.613665      0.250475
# min              1964-04-16 00:00:00      1.000000      0.000009
# 25%              1970-09-04 00:00:00      4.000000      0.058350
# 50%              1986-03-24 00:00:00      7.000000      0.183000
# 75%              2017-12-01 00:00:00     11.000000      0.403750
# max              2022-06-10 00:00:00     47.000000      0.994000
# std                              NaN      6.560220      0.227397
#
#        danceability       energy  instrumentalness    liveness      loudness  \
# count   1610.000000  1610.000000       1610.000000  1610.00000   1610.000000
# mean       0.468860     0.792352          0.164170     0.49173  -6406.640075
# min        0.104000     0.141000          0.000000     0.02190 -24408.000000
# ...

# %%
#AGRUPAR DADOS - Média de Minutos por Album
#df.groupby("Nome_Agrupamento")["Coluna_a_agrupar"].media()
df.groupby("album")["duracao_em_min"].mean()
# Out:
# album
# 12 X 5                              2.682068
# 12 x 5                              2.682772
# A Bigger Bang (2009 Re-Mastered)    4.016356
# A Bigger Bang (Live)                5.176630
# Aftermath                           3.899185
#                                       ...
# Undercover                          4.492750
# Undercover (2009 Re-Mastered)       4.497595
# Voodoo Lounge (Remastered 2009)     4.118779
# Voodoo Lounge Uncut (Live)          5.248507
# got LIVE if you want it!            2.762532
# Name: duracao_em_min, Length: 90, dtype: float64

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 4 Análise Exploratória de Dados (EDA)**

# %%
#Trazer pro Visual, através de Grafico. Qual album tem a maior média
import matplotlib.pyplot as plt

# %%
#sort_values = Ordenar os dados
df_maior_duracao_musica = df.groupby("album")["duracao_em_min"].mean().sort_values(ascending=False)

# %%
df_maior_duracao_musica
# Out:
# album
# Havana Moon (Live)                                                      6.632819
# Bridges To Bremen (Live)                                                6.332265
# Jamming With Edward                                                     6.042794
# Live At The Checkerboard Lounge                                         6.009647
# Totally Stripped - Paris (Live)                                         5.947430
#                                                                           ...
# Out Of Our Heads (UK)                                                   2.464643
# Out Of Our Heads (UK Sequence)                                          2.449274
# December's Children (and everybody's)                                   2.408976
# December’s Children (And Everybody’s)                                   2.408532
# Live 1965: Music From Charlie Is My Darling (Live From England/1965)    2.146082
# Name: duracao_em_min, Length: 90, dtype: float64

# %%
df_maior_duracao_musica.head(5).plot(kind="bar")
plt.xlabel("Albúns")
plt.ylabel("Média de duração das músicas")
plt.title("Top 5 albúns com maior duração média de músicas")
plt.show()

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 5 Análise Exploratória de Dados (EDA)**

# %%
#value_counts = contagem de numeros
top_albuns = df["album"].value_counts().head(10)
plt.barh(top_albuns.index, top_albuns.values)
plt.xlabel("Contagem")
plt.ylabel("Albúns")
plt.title("Top 10 albúns com mais músicas")
plt.show()

# %%
top_albuns
# Out:
# album
# Voodoo Lounge Uncut (Live)         56
# Honk (Deluxe)                      47
# Live Licks                         46
# Tattoo You (Super Deluxe)          46
# Some Girls (Deluxe Version)        44
# Goats Head Soup (Deluxe)           37
# Flashpoint                         34
# Sticky Fingers (Super Deluxe)      33
# On Air (Deluxe)                    32
# Live At The Checkerboard Lounge    32
# Name: count, dtype: int64

# %%
#POPULARIDADE NA ULTIMA DÉCADA - buscando  a ultima decada
df_ultima_decada = df[df["release_date"]. between(pd.to_datetime("2011"), pd.to_datetime("2020"))]

# %%
df_por_album = df_ultima_decada.groupby("album")["popularity"].sum().sort_values(ascending=False).head(10)
df_por_album
# Out:
# album
# Honk (Deluxe)                      1232
# Voodoo Lounge Uncut (Live)          654
# On Air (Deluxe)                     573
# Live At The Checkerboard Lounge     482
# Havana Moon (Live)                  445
# Bridges To Buenos Aires (Live)      433
# Blue & Lonesome                     419
# Bridges To Bremen (Live)            396
# Some Girls: Live In Texas '78       344
# Ladies & Gentlemen (Live)           343
# Name: popularity, dtype: int64

# %%
#Calculo de percentagem
total_popularidade = df_por_album.sum()

df_porcentagem = df_por_album / total_popularidade * 100
df_porcentagem
# Out:
# album
# Honk (Deluxe)                      23.153543
# Voodoo Lounge Uncut (Live)         12.290923
# On Air (Deluxe)                    10.768653
# Live At The Checkerboard Lounge     9.058448
# Havana Moon (Live)                  8.363090
# Bridges To Buenos Aires (Live)      8.137568
# Blue & Lonesome                     7.874460
# Bridges To Bremen (Live)            7.442210
# Some Girls: Live In Texas '78       6.464950
# Ladies & Gentlemen (Live)           6.446157
# Name: popularity, dtype: float64

# %%
#grafico
df_por_album = df_ultima_decada.groupby("album")["popularity"].sum().sort_values(ascending=False).head(10)

total_popularidade = df_por_album.sum()

df_porcentagem = df_por_album / total_popularidade * 100

labels = df_porcentagem.index.tolist()
sizes = df_porcentagem.values.tolist()

figura, grafico = plt.subplots(figsize=(18, 6))
grafico.pie(sizes, autopct="%1.1f%%")
grafico.axis("equal")
plt.title("Porcentagem de Popularidade de Album na Ultima Decada (top 10 Albuns)")
plt.legend(labels, loc = "best")
plt.show()

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 6 Análise Exploratória de Dados (EDA)**
#
# **OUTLIERS**
#
# Usando o SEABORN

# %%
import seaborn as sns

# %%
#PODEMOS USAR O BOXPLOT

#cor de fundo
sns.set(style="whitegrid")

#Estilo do grafico
fig,axes = plt.subplots(figsize=(12,6))

#Bloxpolt somente o eixo x
sns.boxplot(x="duracao_em_min", data=df)

#configuração básica
axes.set_title("Boxplot")

plt.show()

# %%
#GRAFICO VIOLIN
fig, axes = plt.subplots(figsize=(12,6))

#Chamar o grafico de violino (Violin)
sns.violinplot(x="duracao_em_min", data=df, color="gray")

#Definindo eixo X
axes.set_title("Grafico de Violino")

plt.show()

# %%
#Juntar os 2 Graficos
fig, ax = plt.subplots(figsize=(10,6))

#Chamando o violin
sns.violinplot(x="duracao_em_min", data=df, ax=ax, color="lightgray")
#Chamando o boxplot
sns.boxplot(x="duracao_em_min", data=df, ax=ax, whis= 1.5, color="darkblue")

#Titulo
ax.set_title("Visualização Violino e Bloxplot")

plt.show()

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 7 Análise Exploratória de Dados (EDA)**
#
# testar a hipotese dos outliers pra saber se esses pontos são as musicas ao vivo

# %%
df.head()
#Quando temos live no nome podemos imaginar que essas são musicas ao vivo
#Na regra de negocio, a coluna liveness diz que quanto mais próximo de 1 significa que é uma musica ao vivo(um valor acima de 0.8)
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# 0        0.0824         0.463   0.993          0.996000     0.932  -12913.0
# 1        0.4370         0.326   0.965          0.233000     0.961   -4803.0
# 2        0.4160         0.386   0.969          0.400000     0.956   -4936.0
# 3        0.5670         0.369   0.985          0.000107     0.895   -5535.0
# 4        0.4000         0.303   0.969          0.055900     0.966   -5098.0
#
# ...

# %%
#Separação, vamos fazer uma função
def classifica_musica_ao_vivo(df):
  if df["liveness"] >=0.8:
    return True
  else:
    return False

# %%
#Criando uma nova coluna pra trazer o resultado da função   axis=1 para aplicar em coluna
df["ao_vivo"] = df.apply(classifica_musica_ao_vivo, axis=1)
df.head(10)
# Out:
#                           name               album release_date  track_number  \
# 0   Concert Intro Music - Live  Licked Live In NYC   2022-06-10             1
# 1   Street Fighting Man - Live  Licked Live In NYC   2022-06-10             2
# 2           Start Me Up - Live  Licked Live In NYC   2022-06-10             3
# 3  If You Can't Rock Me - Live  Licked Live In NYC   2022-06-10             4
# 4            Don’t Stop - Live  Licked Live In NYC   2022-06-10             5
# 5            Monkey Man - Live  Licked Live In NYC   2022-06-10             6
# 6                 Angie - Live  Licked Live In NYC   2022-06-10             7
# 7          Let It Bleed - Live  Licked Live In NYC   2022-06-10             8
# 8      Midnight Rambler - Live  Licked Live In NYC   2022-06-10             9
# 9         Tumbling Dice - Live  Licked Live In NYC   2022-06-10            10
#
#    acousticness  danceability  energy  instrumentalness  liveness  loudness  \
# ...

# %% [markdown]
# Criar uma separação para fazer uma contagem de quantas musicas temos ao vivo

# %%
#Criar uma separação para fazer uma contagem de quantas musicas temos ao vivo
#df.groupby() = função
#("ao_vivo") = Qual a coluna que vou agrupar a informação
#$["ao_vivo"] = A coluna que vou contabilizar
#.count() = função que vai contar

df.groupby("ao_vivo")["ao_vivo"].count()
# Out:
# ao_vivo
# False    1112
# True      498
# Name: ao_vivo, dtype: int64

# %%
#Separar em 2 df musicas que são ao vivo e musicas de estudio e descobrir a média de cada

#df_gravado_em_estudio = Nome da minha variavel
#df = chamando todo o meu dataframe
# ["ao_vivo"] = Qual a coluna que estou filtrando
# == significa o sinal de igualdade no Python

df_gravado_em_estudio = df[df["ao_vivo"] == False]
df_gravado_ao_vivo = df[df["ao_vivo"] == True]

# %% [markdown]
# Criando uma média

# %%
print("Média das Músicas ao Vivo: ", df_gravado_ao_vivo["duracao_em_min"].mean())
# Out:
# Média das Músicas ao Vivo:  5.088648962516734

# %%
print("Média das Músicas de Estudio: ", df_gravado_em_estudio["duracao_em_min"].mean())
# Out:
# Média das Músicas de Estudio:  3.940451363908873

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 8 Análise Exploratória de Dados (EDA)**

# %%
#barulho das musicas
df_studio = df_gravado_em_estudio.groupby("album")["loudness"].sum()
df_ao_vivo = df_gravado_ao_vivo.groupby("album")["loudness"].sum()

fig,axes = plt.subplots(1,2, figsize=(15,4))


#histplot = histograma  bins=20 configuração do histograma

sns.histplot(data=df_studio, bins=20, ax=axes[0])
axes[0].set_title("soma do barulho das musicas de studio")
axes[0].set_xlabel("Barulho")
axes[0].set_ylabel("Frequencia")

sns.histplot(data=df_ao_vivo, bins=20, ax=axes[1])
axes[1].set_title("soma do barulho das musicas ao vivo")
axes[1].set_xlabel("Barulho")
axes[1].set_ylabel("Frequencia")

fig.tight_layout()
plt.show()

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 9 Análise Exploratória de Dados (EDA)**
#
# Grafico de densidade para analisar a distribuição dos dados

# %%
#Configuração inicial ara criar o grafico, a estrutura para poder colocar um sobre o outro. Vamos comparar as duas escalas.

#cestrutura do grafico
plt.figure(figsize=(10,5))

#kdeplot é o grafico de densidade
sns.kdeplot(data=df_studio, label="Albuns de Studio", fill=True)
sns.kdeplot(data=df_ao_vivo, label="Albuns Ao Vivo", fill=True)


#configirações do grafico
plt.title("Distribuição do barulho dos Albuns")
plt.xlabel("Barulho")
plt.ylabel("Densidade")
plt.legend()
plt.show()

# %% [markdown]
# ESTUDO ESTATÍSTICO PARA SABER SE DE FATO O ALBUNS AO VIVO É MAIS BARULHENTO DO QUE O STUDIO

# %%
from scipy.stats import shapiro

# %%
#Vamos criar duas variaveis

# TESTE DE SHAPIRO

stat, p = shapiro(df_studio)
print("Soma do Barulho dos albuns de studio: ", stat)
print("Estatistica de Teste: {:.4f}, valor p: {} ".format(stat, p))

if p > 0.05:
  print("Não há evidencia suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Soma do Barulho dos albuns de studio:  0.8958151340484619
# Estatistica de Teste: 0.8958, valor p: 3.2961095257633133e-06
# A hipótese de normalidade é rejeitada

# %%
stat, p = shapiro(df_ao_vivo)
print("Soma do Barulho dos albuns ao vivo: ", stat)
print("Estatistica de Teste: {:.4f}, valor p: {} ".format(stat, p))

if p > 0.05:
  print("Não há evidencia suficiente para rejeitar a hipótese de normalidade")
else:
  print("A hipótese de normalidade é rejeitada")
# Out:
# Soma do Barulho dos albuns ao vivo:  0.7913427352905273
# Estatistica de Teste: 0.7913, valor p: 2.35057973441144e-06
# A hipótese de normalidade é rejeitada

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 10 Análise Exploratória de Dados (EDA)**

# %%
#VERIFICAR SE EU TENHO DUAS DISTRIBUIÇÕES DE DADOS QUE SÃO IGUAIS OU NÃO
from scipy.stats import mannwhitneyu

# %%
#sample(tamanho do dataset) = amostra aleatória, pra não viciar a nossa análise, não correr analises enviesadas

stat,p = mannwhitneyu(df_studio.sample(len(df_studio)), df_ao_vivo.sample(len(df_ao_vivo)),alternative="less")


print("Estatistica de Teste U: ",stat)
print("Valor p: ", p)

alpha = 0.05
if p < alpha:
  print("Diferença estatisticamente significante")
else:
  print("Nã há diferença estatisticamente significante")
# Out:
# Estatistica de Teste U:  1367.0
# Valor p:  0.0050727361177996585
# Diferença estatisticamente significante

# %% [markdown]
# **FASE 2 - AULA 2 -EPISÓDIO 11 Análise Exploratória de Dados (EDA)**
#
# ANALISE DE CORRELAÇÃO

# %%
#vAMOS ANALISAR OS DADOS DE VALENCIA\9\Sentimento das Muscas)
#reset_index
media_por_album = df.groupby("album")["valence"].mean().reset_index()

#Coluna para armazenar essa média
media_por_album = media_por_album.rename(columns={"valence":"media_valence"})

#criando uma coluna sntimento que vai analisar a "media_valence" > 0.6 será positiva e abaixo será negativa
media_por_album["sentimento"] = ["positivo" if v >0.6 else "negativo" for v in media_por_album["media_valence"]]
