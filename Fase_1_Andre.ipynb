# %%
#Trazendo a biblioteca Pandas
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np

# %%
import pandas as pd

# Lendo o arquivo CSV
arquivo = pd.read_csv('S:/FIAP/Fase1_Analise_Exploratoria_de_dados/A150850189_28_143_208.csv',
                      encoding="ISO-8859-1",
                      skiprows=3,
                      sep=";",
                      skipfooter=12,
                      thousands=".",
                      decimal=",")

# Selecionando apenas as colunas numéricas
dados_numericos = arquivo.select_dtypes(include='number')

# Preenchendo os valores vazios com 0
dados_preenchidos = dados_numericos.fillna(0)

# Adicionando a coluna "Unidade da Federação" de volta ao DataFrame
dados_preenchidos.insert(0, "Unidade da Federação", arquivo["Unidade da Federação"])

# A variável final é chamada "dados"
dados = dados_preenchidos

# Visualizando o DataFrame
print(dados)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_9284\2070651166.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   arquivo = pd.read_csv('S:/FIAP/Fase1_Analise_Exploratoria_de_dados/A150850189_28_143_208.csv',
#       Unidade da Federação        2007/Ago        2007/Set         2007/Out  \
# 0              11 Rondônia     4209.370000    16397.030000    133645.190000
# 1                  12 Acre    10470.070000    14001.710000     86200.850000
# 2              13 Amazonas    35752.720000    45570.640000    416012.300000
# 3               14 Roraima     4785.910000    11858.630000     43852.670000
# 4                  15 Pará   181159.290000   433414.740000   1893197.500000
# 5                 16 Amapá    33672.740000   104822.980000    118378.280000
# 6             17 Tocantins     4113.760000    76633.060000    343702.610000
# ...

# %%
dados_numericos.mean()
# Out:
# 2007/Ago        304952.774074
# 2007/Set        788145.258519
# 2007/Out       2440162.963704
# 2007/Nov       5517354.049259
# 2007/Dez      12337159.422222
#                   ...
# 2021/Mai      87271862.200741
# 2021/Jun      77590406.465556
# 2021/Jul      60846287.013704
# 2021/Ago      43885716.298519
# Total       6852320913.485186
# Length: 170, dtype: float64

# %%
#Visualizar as 5 primeiras linhas do dataframe
dados.head()
# Out:
#   Unidade da Federação       2007/Ago       2007/Set        2007/Out  \
# 0          11 Rondônia    4209.370000   16397.030000   133645.190000
# 1              12 Acre   10470.070000   14001.710000    86200.850000
# 2          13 Amazonas   35752.720000   45570.640000   416012.300000
# 3           14 Roraima    4785.910000   11858.630000    43852.670000
# 4              15 Pará  181159.290000  433414.740000  1893197.500000
#
#          2007/Nov         2007/Dez         2008/Jan         2008/Fev  \
# 0   346912.840000    711758.310000   1829559.710000   1940792.630000
# 1   301323.680000    769612.360000   1731744.620000   1743978.660000
# 2  2020381.790000   5949408.990000  11419210.080000   7934652.100000
# 3   369328.510000    470676.430000    808448.390000    771687.830000
# 4  5105406.440000  13162823.430000  21762104.160000  20126081.010000
#
#           2008/Mar         2008/Abr  ...         2020/Dez         2021/Jan  \
# ...

# %%
#Visualizar a 5 ultimas linhas do dataframe
dados.tail()
# Out:
#      Unidade da Federação        2007/Ago        2007/Set        2007/Out  \
# 22   43 Rio Grande do Sul  1049252.330000  3182913.140000  8571312.110000
# 23  50 Mato Grosso do Sul   199556.120000   573675.410000  1069816.660000
# 24         51 Mato Grosso    63562.500000   232444.620000   927219.590000
# 25               52 Goiás   179395.820000   418053.580000  1198730.250000
# 26    53 Distrito Federal   191951.470000   769966.250000  2165619.560000
#
#            2007/Nov         2007/Dez         2008/Jan         2008/Fev  \
# 22  16592432.800000  30134255.700000  51064610.030000  45897704.820000
# 23   1995899.520000   4277979.140000   8301006.100000   8279288.790000
# 24   1740439.600000   5394225.430000   8213438.640000   7929894.930000
# 25   2712117.540000   9293914.780000  76052094.770000  18149374.270000
# 26   3813256.480000   7121965.420000  10561085.460000  10215956.800000
#
#            2008/Mar         2008/Abr  ...          2020/Dez          2021/Jan  \
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 171 entries, Unidade da Federação to Total
# dtypes: float64(170), object(1)
# memory usage: 36.2+ KB

# %%
#formatação de ponto flutuante(Formatando os valor de 1.512685e+07 para 15126846.64)
pd.options.display.float_format =  "{: 2f}".format

# %%
#Capturar apenas uma coluna
dados["2008/Ago"]
# Out:
# 0       2938286.290000
# 1       1886871.840000
# 2       8331763.970000
# 3       1045291.110000
# 4      23259148.280000
# 5       1550340.630000
# 6       5213290.380000
# 7      14609872.570000
# 8      10645917.520000
# 9      29304821.510000
# 10     10812840.190000
# 11     12673774.350000
# 12     31705296.790000
# 13      9262767.680000
# 14      4543252.500000
# 15     43254543.330000
# 16     80374117.080000
# 17     12384068.190000
# 18     42502172.220000
# 19    180097396.030000
# 20     56699001.130000
# 21     28887854.620000
# 22     56233758.740000
# 23      9602843.490000
# 24      8987811.950000
# 25     21070201.360000
# 26     11548451.890000
# Name: 2008/Ago, dtype: float64

# %%
#Média da Serie capturada
dados["2008/Ago"].mean()
# Out:
# 26645398.35703704

# %%
#PLOTAR os dados, ou seja quero criar uma analise de um determinado dado#
dados.plot(x = "Unidade da Federação", y = "2008/Ago")
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados.plot(x = "Unidade da Federação", y = "2008/Ago", kind='bar')
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
#AUMENTANDO O TAMANHO DA SAIDA DOS DADOS
import matplotlib.ticker as ticker
axis = dados.plot(x = "Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))

# %%
#FORMATANDO O NUMERO DA SAIDA DOS DADOS
import matplotlib.ticker as ticker
axis = dados.plot(x = "Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

# %%
#COLOCANDO UM TITULO NO GRAFICO

import matplotlib.pyplot as plt

axis = dados.plot(x = "Unidade da Federação", y = "2008/Ago", kind='bar', figsize=(9,6))
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("VALOR PO R UNIDADE DE FEDERAÇÃO")

#Para mostrar esse grafico
plt.show()

# %%
#VISUALIZAR TODAS AS COLUNAS DO ARQUIVO
dados.columns
# Out:
# Index(['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        '2008/Mai', '2008/Jun', '2008/Jul', '2008/Ago', '2008/Set',
#        ...
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai',
#        '2021/Jun', '2021/Jul', '2021/Ago', 'Total'],
#       dtype='object', length=165)

# %%
#Capturar mais de uma coluna(serie)
dados[["2008/Ago", "2008/Set", "2021/Mar"]]
# Out:
#             2008/Ago          2008/Set          2021/Mar
# 0     3231494.610000    3117178.630000   14946369.280000
# 1     2089107.140000    2275708.530000    4077045.920000
# 2     9352532.700000    9363099.350000   23445832.760000
# 3      894271.180000     910424.170000    4437161.100000
# 4    23341218.030000   25172261.320000   40639703.770000
# 5     1475551.380000    1651341.430000    3188210.980000
# 6     5413710.380000    5596669.500000   10651036.240000
# 7    15195312.890000   14951277.750000   44534337.620000
# 8    10549176.400000   10899198.970000   21609265.950000
# 9    27851438.720000   30362719.900000   68360158.150000
# 10   10640817.470000   11336030.280000   28444100.380000
# 11   12872578.370000   12558296.110000   26404374.310000
# 12   35457038.660000   33668261.460000   87933693.440000
# 13    9373432.000000    9563580.500000   22323051.110000
# 14    5238398.500000    5187912.190000   13507023.710000
# ...

# %%
#CAPTURAR UMA SERIE ISOLADA NO DATAFRAME
dados["2008/Ago"]
# Out:
# 0       3231494.610000
# 1       2089107.140000
# 2       9352532.700000
# 3        894271.180000
# 4      23341218.030000
# 5       1475551.380000
# 6       5413710.380000
# 7      15195312.890000
# 8      10549176.400000
# 9      27851438.720000
# 10     10640817.470000
# 11     12872578.370000
# 12     35457038.660000
# 13      9373432.000000
# 14      5238398.500000
# 15     46931248.280000
# 16     84722528.100000
# 17     12588595.770000
# 18     50912706.600000
# 19    184854516.350000
# 20     56982774.900000
# 21     31250854.330000
# 22     56113054.700000
# 23      9671553.450000
# 24      9243148.810000
# 25     20650730.670000
# 26     13710857.890000
# Name: 2008/Ago, dtype: float64

# %%
#MÉDIA DA SERIE CAPTURADA
dados["2008/Ago"].mean()
# Out:
# 27800320.306666665

# %%
#MÉDIA DA SERIE CAPTURADA
dados[["2008/Ago", "2008/Set", "2021/Mar"]].mean()
# Out:
# 2008/Ago    27800320.306667
# 2008/Set    27887505.264815
# 2021/Mar    66569186.631111
# dtype: float64

# %%
#VISUALIZAR TODAS AS COLUNAS DO ARQUIVO
dados.columns
# Out:
# Index(['Unidade da Federação', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr',
#        '2008/Mai', '2008/Jun', '2008/Jul', '2008/Ago', '2008/Set',
#        ...
#        '2020/Dez', '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai',
#        '2021/Jun', '2021/Jul', '2021/Ago', 'Total'],
#       dtype='object', length=165)

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#           2008/Ago         2008/Set
# 0   3231494.610000   3117178.630000
# 1   2089107.140000   2275708.530000
# 2   9352532.700000   9363099.350000
# 3    894271.180000    910424.170000
# 4  23341218.030000  25172261.320000

# %%
dados.head()
# Out:
#   Unidade da Federação         2008/Jan         2008/Fev         2008/Mar  \
# 0          11 Rondônia   1388528.390000   2931283.420000   1541682.520000
# 1              12 Acre    902416.000000   1497206.260000   1794028.480000
# 2          13 Amazonas   4735529.420000   7118990.570000   8196635.490000
# 3           14 Roraima    657889.530000    777939.310000    718688.030000
# 4              15 Pará  18864744.110000  19553758.200000  21937342.700000
#
#           2008/Abr         2008/Mai         2008/Jun         2008/Jul  \
# 0   1525314.960000   1645953.840000   1406150.680000   3065279.010000
# 1   1730469.420000   1819443.920000   1828496.000000   2511754.590000
# 2   8259378.420000   7831399.900000   8477273.620000   9368858.720000
# 3    839994.390000    862347.960000    832440.660000    996693.090000
# 4  20842829.690000  23249952.880000  23240687.560000  24002223.560000
#
#           2008/Ago         2008/Set  ...         2020/Dez         2021/Jan  \
# ...
